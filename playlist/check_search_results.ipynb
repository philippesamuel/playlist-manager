# %%
import json

with open("search_result2.json", "r") as f:
    data = json.load(f)

for item in data["tracks"]["items"]:
    print(item["id"], item["name"], sep="\t")
    print([a["name"] for a in item["artists"]])
# Out:
# 1qxDqbzmWODOkr0Ja5Iotz	Agnus Dei - Live
# ['Michael W. Smith']
# 1N9SysNAP8j4wbAIHzlM9m	Agnus Dei
# ['Michael W. Smith']
# 6FnD62i17Yb1gd2RBS1x30	Agnus Dei
# ['Michael W. Smith', 'Skye Reedy']
# 6UBSkuhGbocJjyAq3ZuULZ	Agnus Dei
# ['Michael W. Smith']
# 75epGNrtShqtqCwILdpRRp	Agnus Dei
# ['Michael W. Smith']
# 6u2N3zMvMTe2nLiG8xwkQw	Agnus Dei - Live From Passion 2024
# ['Passion', 'Kristian Stanfill']
# 1ipQpRlDxZbjMd95MDdcTc	Agnus Dei - Live
# ['Michael W. Smith', 'Amy Grant']
# 2GwhmLK4T0l15MRxy56PCu	Agnus Dei / King of Kings
# ['Hillsong Worship', 'Passion', 'Chidima', 'Jenn Johnson', 'Brooke Ligertwood']
# 4PlxtUiHOrg5ZwEp0aJSuh	Agnus Dei - Live
# ['Michael W. Smith', 'Skye Reedy']
# 413WwV7PwLEzImYBCRqk6t	Agnus Dei - Live
# ['Michael W. Smith']
# 3iyJqJuRE1QlQbkgEV9sWS	The Tribute / Agnus Dei
# ['Michael W. Smith']
# 4KNYoD13f3o5p3SRkR7FTr	Agnus Dei - Instrumental
# ['Michael W. Smith']
# 5UrQsuWJEnTA8pXkLQG0p6	Agnus Dei - Live
# ['Michael W. Smith']
# ...

# %%
data["tracks"]["items"]
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0bz9hDpUbAw5JElgEiuIYZ'},
#      'href': 'https://api.spotify.com/v1/artists/0bz9hDpUbAw5JElgEiuIYZ',
#      'id': '0bz9hDpUbAw5JElgEiuIYZ',
#      'name': 'Matt Redman',
#      'type': 'artist',
#      'uri': 'spotify:artist:0bz9hDpUbAw5JElgEiuIYZ'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0av22wHGgPZRC0BkGrnVVJ'},
#    'href': 'https://api.spotify.com/v1/albums/0av22wHGgPZRC0BkGrnVVJ',
#    'id': '0av22wHGgPZRC0BkGrnVVJ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273452e18e0a213a15cb09908f2',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02452e18e0a213a15cb09908f2',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851452e18e0a213a15cb09908f2',
#      'width': 64}],
#    'is_playable': True,
# ...
